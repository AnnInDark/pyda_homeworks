# %% [markdown]
# # Домашнее задание к лекции "Основы веб-скрапинга и работы с API"

# %% [markdown]
# ## Задание 1.
#
# ### Обязательная часть

# %% [markdown]
# Будем парсить страницу со свежеми новостям на [habr.com/ru/all/](https://habr.com/ru/all/).
#
# Вам необходимо собирать только те статьи, в которых встречается хотя бы одно требуемое ключевое слово. Эти слова определяем в начале кода в переменной, например:
#
# `KEYWORDS = ['python', 'парсинг']`
#
#  Поиск вести по всей доступной preview-информации (это информация, доступная непосредственно с текущей страницы).
#
# В итоге должен формироваться датафрейм вида: `<дата> - <заголовок> - <ссылка>`

# %% [markdown]
# ### Дополнительная часть (необязательная)

# %% [markdown]
# Улучшить скрипт так, чтобы он анализировал не только preview-информацию статьи, но и весь текст статьи целиком.
#
# Для этого потребуется получать страницы статей и искать по тексту внутри этой страницы.
#
# Итоговый датафрейм формировать со столбцами: `<дата> - <заголовок> - <ссылка> - <текст_статьи>`

# %% [markdown]
# ### Решение

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime

KEYWORDS = ['python', 'парсинг']

# получаем страницу с самыми свежими постами
req = requests.get('https://habr.com/ru/all/')
soup = BeautifulSoup(req.text, 'html.parser')

# извлекаем ссылки на посты
post_links = list(map(lambda x: x.find('a', class_='post__title_link').get('href'), soup.find_all('article', class_='post')))

# Подготавливаем датафрейм
res = pd.DataFrame(columns=['post_dt', 'header', 'link', 'body'])

# Проходимся по ссылкам
for link in post_links:
    # Собираем необходимые данные со страницы
    page = BeautifulSoup(requests.get(link).text, 'html.parser')
    header = page.find('span', class_='post__title-text').text
    post_dt = datetime.strptime(page.find('span', class_='post__time').get('data-time_published'), '%Y-%m-%dT%H:%MZ')
    body = page.find('div', id='post-content-body').text
    # Проверяем подходят ли нам по кейвордам и если подходят добавляем в дф-результат
    for kv in KEYWORDS:
        if kv in header or kv in body:
            res = res.append({x:eval(x) for x in ['post_dt', 'header', 'link', 'body']}, ignore_index=True)

res

# Единственное что в текстах теряются абзацы :(
# Out:
#               post_dt                                             header  \
# 0 2021-04-05 11:19:00              Полезности для разработчика на Django
# 1 2021-04-05 10:47:00  Magento 2 UI Components. Часть 1: общее устрой...
# 2 2021-04-05 10:45:00  Impala для Python-разработчика на примере опре...
#
#                                                 link  \
# 0                   https://habr.com/ru/post/550784/
# 1      https://habr.com/ru/company/rshb/blog/550772/
# 2  https://habr.com/ru/company/wargaming/blog/550...
#
#                                                 body
# 0  ПредисловиеДля написания данной статьи был изу...
# 1  Привет! Меня зовут Павел и я Magento 2 бэкенд-...
# 2  Всем привет.Как известно, есть множество разли...

# %% [markdown]
# ## Задание 2.

# %% [markdown]
# ### Обязательная часть

# %% [markdown]
# Написать скрипт, который будет проверять список e-mail адресов на утечку при помощи сервиса [Avast Hack Ckeck](https://www.avast.com/hackcheck/).
# Список email-ов задаем переменной в начале кода:
# `EMAIL = [xxx@x.ru, yyy@y.com]`
#
# В итоге должен формироваться датафрейм со столбцами: `<почта> - <дата утечки> - <источник утечки> - <описание утечки>`
#
# **Подсказка**: сервис работает при помощи "скрытого" API. Внимательно изучите post-запросы.

# %% [markdown]
# ### Решение

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime
import json
import re

EMAIL = ['xxx@xx.ru', 'yyy@yy.com']

URL = 'https://identityprotection.avast.com/v1/web/query/site-breaches/unauthorized-data'

params = {
    'emailAddresses': EMAIL
}
headers = {
    'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.198 Safari/537.36'
    ,'Vaar-Header-App-Build-Version': '1.0.0'
    ,'Vaar-Version': '0'
    ,'Vaar-Header-App-Product-Name': 'hackcheck-web-avast'
}

req = requests.post(URL, headers=headers, json=params)

soup = BeautifulSoup(req.content, 'html.parser')

dres = json.loads(soup.text)

# Подготавливаем датафрейм
res = pd.DataFrame(columns=['email', 'dt_leaks', 'source_leaks', 'dt_published',  'description'])

e2l = {}
# Определяем какие имейлы были в каких утечках
for k, v in dres['summary'].items():
    e2l[k] = v['breaches']

    
# Смотрим сливы
for d in dres['breaches'].values():
    try:
        dt_published = datetime.strptime(d['publishDate'], '%Y-%m-%dT%H:%M:%SZ')
        source_leaks = d['site']
        description = d['description']
        # доставая дату из текста описания утечки получается довольно неоднозначно.
        # Так что либо в задании имелась ввиду дата публикации, а не утечки, либо просто не получилось нормально достать дату утечки из статьи.
        dt_leaks = ' '.join(re.findall(r'[0-9]{4}|\b{Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec}*', description))
#         Смотрим к какому из исходных имейлов относятся сливы, фиксируем ответ
        for k,v in e2l.items():
            if d['breachId'] in v:
                email = k
                res = res.append({x:eval(x) for x in ['email', 'dt_leaks', 'source_leaks', 'dt_published', 'description']}, ignore_index=True)
    except:
        pass

res
# Out:
#          email            dt_leaks                source_leaks dt_published  \
# 0   yyy@yy.com            Oct 2015              ir.netease.com   2016-11-07
# 1   yyy@yy.com           2015 2016           crackingforum.com   2017-01-31
# 2   yyy@yy.com            Nov 2020  onlinepsychometrictest.com   2020-12-17
# 3   yyy@yy.com                                       hiapk.com   2017-09-07
# 4    xxx@xx.ru                                   gamma.mmdm.ru   2021-01-07
# 5   yyy@yy.com                                       romwe.com   2020-04-02
# 6   yyy@yy.com                2018                   chegg.com   2018-08-24
# 7   yyy@yy.com            Jun 2020                 wattpad.com   2020-07-23
# 8   yyy@yy.com       2016 Jun 2013                 myspace.com   2016-10-21
# 9   yyy@yy.com                                   azcentral.com   2020-01-03
# 10  yyy@yy.com            Jun 2018                   shein.com   2019-05-16
# 11  yyy@yy.com            Nov 2016                   im286.net   2017-04-14
# 12   xxx@xx.ru                                      storelp.ru   2018-06-19
# 13  yyy@yy.com   Dec 2011 Dec 2011                 dodonew.com   2017-06-01
# 14  yyy@yy.com            Oct 2017              myheritage.com   2017-11-04
# 15  yyy@yy.com            May 2019                   canva.com   2019-06-13
# 16   xxx@xx.ru            Nov 2020                china232.com   2020-12-10
# 17  yyy@yy.com            Oct 2016                    gfan.com   2018-06-12
# 18  yyy@yy.com  2012 Aug 2016 2012                 dropbox.com   2016-10-24
# 19  yyy@yy.com            Nov 2020          3740nlakeshore.com   2020-12-03
# 20  yyy@yy.com   Dec 2011 Dec 2011                    csdn.net   2017-06-24
# 21  yyy@yy.com            Mar 2015                   gaadi.com   2017-09-16
# 22   xxx@xx.ru                              xrumer.winguild.ru   2019-09-12
# 23  yyy@yy.com            Sep 2019                   zynga.com   2019-10-17
# 24   xxx@xx.ru       2012 Jun 2016                      vk.com   2016-10-29
# 25  yyy@yy.com        Jun 2016 Nov               readnovel.com   2019-06-13
# 26  yyy@yy.com                                        52pk.com   2020-11-12
# 27  yyy@yy.com            Dec 2020                 joygames.me   2021-01-07
# 28  yyy@yy.com   Sep 2016 Sep 2016               clixsense.com   2017-06-01
# 29   xxx@xx.ru            Oct 2013                   adobe.com   2016-10-21
# 30  yyy@yy.com            Oct 2013                   adobe.com   2016-10-21
# 31  yyy@yy.com   Jul 2018 Dec 2012                  netlog.com   2018-02-18
# 32  yyy@yy.com            Sep 2020                  eatigo.com   2020-11-19
# 33  yyy@yy.com                                       jdbbx.com   2017-02-21
# 34  yyy@yy.com            Nov 2020             4170nmarine.com   2020-12-03
# 35  yyy@yy.com                2020                 mathway.com   2020-05-28
# 36   xxx@xx.ru            Jun 2020               learnable.com   2021-02-11
# 37   xxx@xx.ru        Jul Aug 2016               cfire.mail.ru   2017-02-14
# 38  yyy@yy.com       Oct 2011 2012               kaixin001.com   2017-03-23
# 39  yyy@yy.com            Nov 2020              505mcclurg.com   2020-12-03
# 40   xxx@xx.ru            Jun 2016                   imesh.com   2016-10-23
# 41  yyy@yy.com            Jun 2016                   imesh.com   2016-10-23
# 42  yyy@yy.com                                       tgbus.com   2017-09-07
# 43  yyy@yy.com       2016 Apr 2017                   youku.com   2017-03-24
#
#                                           description
# 0   In October 2015, the Chinese internet and gami...
# 1   In 2015, hacker website CrackingForum.com's us...
# 2   In November 2020, a collection of over 23,000 ...
# 3   Chinese technology site HIAPK.com's user datab...
# 4   At an unconfirmed date the home page for the R...
# 5   At an unconfirmed date, the online fashion ret...
# 6   In 2018, education tech company Chegg's databa...
# 7   In June 2020, the online writing community Wat...
# 8   Shortly before the 2016 Memorial Day weekend, ...
# 9   At an unconfirmed date, online Arizona newspap...
# 10  In June 2018, fast-fashion retailer Shein's da...
# 11  In November 2016, Im286.net's user database wa...
# 12  At an unconfirmed date, StoreLP.ru's database ...
# 13  In December 2011, Chinese software company Dod...
# 14  In October 2017, a customer database belonging...
# 15  In May 2019, graphic-design site Canva's datab...
# 16  In November 2020, a collection of over 23,000 ...
# 17  In October 2016, Machine Front Network's datab...
# 18  Cloud storage company Dropbox suffered a major...
# 19  In November 2020, a collection of over 23,000 ...
# 20  In December 2011, CSDN's user database was all...
# 21  In March 2015, Gaadi's user database was alleg...
# 22  At an unconfirmed date, Russian audio equipmen...
# 23  In September 2019, the game developer Zynga wa...
# 24  Popular Russian social networking platform VKo...
# 25  In June 2016, fan fiction site ReadNovel's dat...
# 26  At an unconfirmed date, the Chinese gaming web...
# 27  In December 2020, the online gaming website Jo...
# 28  In September 2016, ClixSense's user database w...
# 29  In October of 2013, criminals penetrated Adobe...
# 30  In October of 2013, criminals penetrated Adobe...
# 31  Netlog (formerly known as Facebox and Bingbox)...
# 32  In September 2020, the Asian restaurant reserv...
# 33  JDBBX's user database was allegedly breached. ...
# 34  In November 2020, a collection of over 23,000 ...
# 35  In January 2020, the online math problem solvi...
# 36  In June 2020, the site Learnable was allegedly...
# 37  In July and August of 2016, two criminals carr...
# 38  In October 2011, some of Chinese social media ...
# 39  In November 2020, a collection of over 23,000 ...
# 40  In June 2016, a cache of over 51 million user ...
# 41  In June 2016, a cache of over 51 million user ...
# 42  On an unconfirmed date, Chinese video gate sit...
# 43  Youku is a large Chinese video content company...

# %% [markdown]
# ### Дополнительная часть (необязательная)

# %% [markdown]
# Написать скрипт, который будет получать 50 последних постов указанной группы во Вконтакте.
# Документация к API VK: https://vk.com/dev/methods
# , вам поможет метод [wall.get](https://vk.com/dev/wall.get)
# ```
# GROUP = 'netology'
# TOKEN = УДАЛЯЙТЕ В ВЕРСИИ ДЛЯ ПРОВЕРКИ, НА GITHUB НЕ ВЫКЛАДЫВАТЬ
# ```
#
# В итоге должен формироваться датафрейм со столбцами: `<дата поста> - <текст поста>`

# %% [markdown]
# ### Решение

# %%
import requests
import pandas as pd
from datetime import datetime

access_token = ''

# Не сразу увидела, что в метод wall.get можно передавать алиас сообщества/группы, поэтому сначала доставала ид по алиасу отдельным действием
params = {
    'group_id':'netology'
    , 'fields':'owner_id'
    , 'access_token':access_token
    , 'v':'5.103'
}

# Получаем ид сообщества
req = requests.get('https://api.vk.com/method/groups.getById', params)
group_id = req.json()['response'][0]['id']

# Подготавливаем датафрейм
res = pd.DataFrame(columns=['dt_published',  'post_text'])

# забираем записи стены
params = {
    'owner_id':'-' + str(group_id)
    , 'fields':'owner_id'
    , 'access_token':access_token
    , 'v':'5.103'
    , 'domain':'netology'
    , 'count':50
}
req = requests.get('https://api.vk.com/method/wall.get', params)

for x in req.json()['response']['items']:
    dt_published = datetime.fromtimestamp(x['date'])
    post_text = x['text']
    res = res.append({x:eval(x) for x in ['dt_published', 'post_text']}, ignore_index=True)

    
res
# Out:
#           dt_published                                          post_text
# 0  2021-04-02 10:18:00  Пишем коды для веб-страниц, осваиваем языки пр...
# 1  2021-04-05 10:16:00  🚀 Запустили бесплатный курс «Основы интернет-м...
# 2  2021-04-04 13:52:00  Мы знаем, что найти работу не всегда легко 🤗 \...
# 3  2021-04-03 15:25:00  *партнёрский пост* \n \n15 апреля состоится он...
# 4  2021-04-03 13:46:00  Чтобы писать красиво, просто и понятно — недос...
# 5  2021-04-01 18:46:00  Прокрастинация — это когда нужно работать здес...
# 6  2021-04-01 11:15:00  Чтобы сменить специальность, нужно признать, ч...
# 7  2021-03-31 15:32:32  Разыгрываем 10 доступов к библиотеке видеокурс...
# 8  2021-03-31 10:49:00  Кажется, в SMM всё просто: написал пост, ответ...
# 9  2021-03-30 17:49:00  В 2020 году сербская художница-перформанистка ...
# 10 2021-03-30 10:35:47  В новом выпуске НетоNews рассказали про самые ...
# 11 2021-03-29 18:18:00  ❌ Бросить попытки после первой неудачи \n❓Учит...
# 12 2021-03-29 10:44:00  Записывайтесь на бесплатный курс «Диджитал-ста...
# 13 2021-03-28 16:25:00  Вместе с сервисом Bookmate запустили квиз по к...
# 14 2021-03-28 12:23:00  Всё, что окружает нас в повседневной жизни так...
# 15 2021-03-27 15:57:00  В этой афише мероприятий онлайн-эфир о развити...
# 16 2021-03-27 12:08:00  Разместить ссылку на свой сайт — это тоже свое...
# 17 2021-03-26 16:57:00  Каждый день дизайнеры меняют IT и digital, фор...
# 18 2021-03-26 10:44:00  Точно решили, кем хотите стать в диджитале, но...
# 19 2021-03-25 18:17:00  Мудборд — неотъемлемая часть подготовки любого...
# 20 2021-03-25 11:10:00  Почему Java лучший выбор для новичка, какие на...
# 21 2021-03-24 16:57:00  Что для вас важнее всего в работе? \nКому-то д...
# 22 2021-03-24 10:27:00  🚀 Запустили бесплатный курс «Основы Figma» \n ...
# 23 2021-03-23 17:16:00  Если вы знаете английский язык — у вас могут б...
# 24 2021-03-23 11:16:00  В новом выпуске НетоNews обсудим изменение поз...
# 25 2021-03-22 17:46:00  Что общего между лентой новостей в Инстаграм и...
# 26 2021-03-22 10:36:00  🚀 30 марта стартует бесплатный онлайн-курс «Пс...
# 27 2021-03-21 18:41:00  🎁 Запустили страницу с подарками и скидками от...
# 28 2021-03-21 11:10:00  Решиться на перемены — всегда непросто. Решить...
# 29 2021-03-20 16:22:00  В этой афише мероприятий конференции для дизай...
# 30 2021-03-20 15:22:00  *партнёрский пост* \n \n29 марта на сайте m-i-...
# 31 2021-03-20 13:46:00  Задача геймдизайнера не только нарисовать игру...
# 32 2021-03-19 16:36:00  Произведения искусства, которыми мы пользуемся...
# 33 2021-03-19 11:02:00  Я новичок, у меня совершенно нет опыта! 😰 \n \...
# 34 2021-03-18 18:11:00  Мы сталкиваемся с аналитикой гораздо чаще, чем...
# 35 2021-03-18 11:00:09  Вместе в природой просыпается накопившаяся за ...
# 36 2021-03-17 16:25:03  Весна — лучшее время для перемен. Чтобы узнать...
# 37 2021-03-17 10:46:00  🚀 29 марта стартует бесплатный онлайн-марафон ...
# 38 2021-03-16 17:46:00  Рано или поздно у любого копирайтера, SMM-мене...
# 39 2021-03-16 10:48:00  В новом выпуске НетоNews поговорим о частичной...
# 40 2021-03-15 18:09:00  Как на удалёнке выстроить хорошие к коллегами ...
# 41 2021-03-15 10:55:28  🔥 27 марта пройдёт бесплатный митап «Аналитика...
# 42 2021-03-14 12:49:00  Говорят, лидерами не рождаются, а становятся 😎...
# 43 2021-03-13 12:53:00  Выстраивать отношения с коллегами, решать зада...
# 44 2021-03-12 17:47:00  В эфире #пятничнаябеседка. Здесь мы обсуждаем,...
# 45 2021-03-12 11:11:00  Настраиваем рекламные кабинеты, пишем сценарий...
# 46 2021-03-11 17:53:00  Даже самый уверенный в себе человек испытывает...
# 47 2021-03-11 11:40:00  Интернет — пространство безграничных возможнос...
# 48 2021-03-10 17:40:00  Проверим, насколько хорошо вы знаете нас 😉 \nЗ...
# 49 2021-03-10 10:53:00  🔥 15 марта стартует бесплатный курс «Как стать...
